# %%
import sys
from pathlib import Path

# %%
# Add parent directory to path so we can import src
sys.path.insert(0, str(Path.cwd().parent))

from src.dataloader import load_data

df = load_data()
print(df.head())
# Out:
#              faction  winrate  overrep  fourzerostart  eventwins  \
# 0            Aeldari       55     1.58             12        166
# 1  Genestealer Cults       54     1.54             12         57
# 2      Thousand Sons       53     1.27             10         58
# 3   Adepta Sororitas       52     1.33             11         71
# 4            Necrons       52     1.14              9        105
#
#    playerpopulation
# 0                 5
# 1                 2
# 2                 3
# 3                 3
# 4                 6
