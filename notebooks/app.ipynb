# %%
from src.dataloader import load_data

df = load_data()
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.dataloader import load_data
# ----> 3 df = load_data()
#       4 print(df.head())
#
# File c:\Users\ralah\Documents\Koodiprojektit\Warhammer project\Fun-Warhammer-project\src\dataloader.py:13, in load_data()
#      11 df = pd.read_csv(DATA_PATH, quoting=3)
#      12 df = _standardize_column_names(df)
# ---> 13 _validate_data(df) #Placeholder for data validation function
#      14 return df
#
# File c:\Users\ralah\Documents\Koodiprojektit\Warhammer project\Fun-Warhammer-project\src\dataloader.py:39, in _validate_data(df)
#      37 if not excepted_columns.issubset(df.columns):
#      38     missing_cols = set(excepted_columns) - set(df.columns)
# ---> 39     raise ValueError(f"Missing columns in the data: {missing_cols}")
#      41 if df.isnull().values.any():
# ...
